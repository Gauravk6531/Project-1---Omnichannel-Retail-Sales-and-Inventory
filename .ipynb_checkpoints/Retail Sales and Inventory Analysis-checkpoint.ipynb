# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %%
df_sales = pd.read_csv(r"C:\Users\ASUS\Desktop\Desktop\Infotact Internship\Project 1 clean\Project-1-Omnichannel-retail-analysis-clean\cleaned_data\retail_sales_cleaned.csv")
df_inv = pd.read_csv(r"C:\Users\ASUS\Desktop\Desktop\Infotact Internship\Project 1 clean\Project-1-Omnichannel-retail-analysis-clean\cleaned_data\retail_inventory_cleaned.csv")

# %%
df_inv.isna().sum()
df_inv.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 284755 entries, 0 to 284754
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   start_date                284755 non-null  str
#  1   end_date                  284755 non-null  str
#  2   stock_status              284755 non-null  str
#  3   supplier                  284755 non-null  str
#  4   product_no                284755 non-null  str
#  5   product_description       284755 non-null  str
#  6   product_division          284755 non-null  str
#  7   product_category          284755 non-null  str
#  8   product_subcategory       284755 non-null  str
#  9   product_segment           284755 non-null  str
#  10  store                     284755 non-null  str
#  11  store_type                284755 non-null  str
#  12  sales_channel             284755 non-null  str
#  13  qty_on_hand               284755 non-null  int64
#  14  stocks_selling_amount     284755 non-null  float64
#  15  cost_of_stocks            284755 non-null  float64
#  16  stock_unit_selling_price  284755 non-null  float64
#  17  stock_unit_cost_price     284755 non-null  float64
# dtypes: float64(4), int64(1), str(13)
# memory usage: 114.2 MB

# %%
df_inv.head()
# Out:
#    start_date    end_date stock_status     supplier   product_no  \
# 0  2025-08-07  2025-10-18   Full Price  Vendor 0255  PROD-159369
# 1  2026-02-15  2026-02-15   Full Price  Vendor 0010  PROD-180713
# 2  2026-01-08  2026-02-15   Full Price  Vendor 0166  PROD-169474
# 3  2025-12-23  2026-02-15   Full Price  Vendor 0106  PROD-170976
# 4  2026-02-10  9999-12-31   Full Price  Vendor 0134  PROD-183525
#
#                                  product_description  product_division  \
# 0  PROD-103395 SEG-500461 Scholar Footwear Canvas...  Scholar Footwear
# 1  PROD-190644 SEG-520887 Femme Footwear Court Ca...    Femme Footwear
# 2  PROD-153439 SEG-512518 Femme Footwear Court Ca...    Femme Footwear
# 3  PROD-122029 SEG-504463 Junior Apparel Cozy Pul...    Junior Apparel
# 4  PROD-111954 SEG-502325 Scholar Footwear Modern...  Scholar Footwear
#
#                  product_category                     product_subcategory  \
# 0  Scholar Footwear Canvas Styles  Scholar Footwear Canvas Styles Drifter
# 1     Femme Footwear Court Casual     Femme Footwear Court Casual Trident
# 2     Femme Footwear Court Casual      Femme Footwear Court Casual Zephyr
# 3   Junior Apparel Cozy Pullovers    Junior Apparel Cozy Pullovers Varied
# 4  Scholar Footwear Modern Legend   Scholar Footwear Modern Legend Summit
#
#                                      product_segment     store  \
# 0  SEG-500461 Scholar Footwear Canvas Styles Drifter  STR-1010
# 1     SEG-520887 Femme Footwear Court Casual Trident  STR-1082
# 2      SEG-512518 Femme Footwear Court Casual Zephyr  STR-1105
# 3    SEG-504463 Junior Apparel Cozy Pullovers Varied  STR-1157
# 4   SEG-502325 Scholar Footwear Modern Legend Summit  STR-1253
#
#           store_type  sales_channel  qty_on_hand  stocks_selling_amount  \
# 0  Retail Storefront  Channel Alpha            1                   55.0
# 1  Retail Storefront  Channel Alpha            1                  130.0
# 2  Retail Storefront  Channel Alpha            1                  120.0
# 3  Retail Storefront  Channel Alpha            3                  150.0
# 4  Retail Storefront  Channel Alpha            4                  360.0
#
#    cost_of_stocks  stock_unit_selling_price  stock_unit_cost_price
# 0           24.75                      55.0                  24.75
# 1           59.73                     130.0                  59.73
# 2           60.44                     120.0                  60.44
# 3           52.50                      50.0                  17.50
# 4          182.16                      90.0                  45.54

# %%
df_sales.head()
# Out:
#   transaction_date  sales_type  is_return     supplier   product_no  \
# 0       2025-09-01  Full Price          0  Vendor 0169  PROD-139867
# 1       2025-09-07  Full Price          0  Vendor 0166  PROD-100449
# 2       2025-08-06       Promo          0  Vendor 0169  PROD-153623
# 3       2025-08-31  Full Price          0  Vendor 0246  PROD-140876
# 4       2026-03-22  Full Price          0  Vendor 0169  PROD-166113
#
#                                  product_description  product_division  \
# 0  PROD-100449 SEG-500065 Scholar Footwear Trailb...  Scholar Footwear
# 1  PROD-100825 SEG-500112 Heritage Footwear Fligh...    Femme Footwear
# 2  PROD-148813 SEG-511388 Scholar Footwear Trailb...  Scholar Footwear
# 3  PROD-100419 SEG-500063 Scholar Footwear Boot C...  Scholar Footwear
# 4  PROD-149345 SEG-511444 Femme Footwear Trailbla...    Femme Footwear
#
#                    product_category  \
# 0      Scholar Footwear Trailblazer
# 1     Femme Footwear Flight Classic
# 2      Scholar Footwear Trailblazer
# 3  Scholar Footwear Boot Collection
# 4        Femme Footwear Trailblazer
#
#                          product_subcategory  \
# 0   Scholar Footwear Trailblazer Equilibrium
# 1       Femme Footwear Flight Classic Varied
# 2   Scholar Footwear Trailblazer Equilibrium
# 3  Scholar Footwear Boot Collection Woodland
# 4     Femme Footwear Trailblazer Equilibrium
#
#                                      product_segment     store  sales_channel  \
# 0  SEG-500065 Scholar Footwear Trailblazer Equili...  STR-1006  Channel Alpha
# 1  SEG-500112 Heritage Footwear Flight Classic Ze...  STR-1198  Channel Alpha
# 2  SEG-511388 Scholar Footwear Trailblazer Equili...  STR-1157  Channel Alpha
# 3  SEG-500063 Scholar Footwear Boot Collection Wo...  STR-1234  Channel Alpha
# 4  SEG-511444 Femme Footwear Trailblazer Equilibrium  STR-1157  Channel Alpha
#
#    qty_sold  sales_amount   cogs  number_of_transactions
# 0       1.0        115.00  52.31                       1
# 1       1.0        115.00  58.47                       1
# 2       1.0         79.99  43.76                       1
# 3       1.0        110.00  50.60                       1
# 4       1.0        160.00  77.95                       1

# %%
df_sales['transaction_date'] = pd.to_datetime( df_sales['transaction_date'], format='mixed', dayfirst=True)
df_inv['start_date'] = pd.to_datetime(df_inv['start_date'], )
df_inv['end_date'] = pd.to_datetime(df_inv['end_date'], errors='coerce')

# %% [markdown]
# ### Important Time Columns

# %%
df_sales['year'] = df_sales['transaction_date'].dt.year
df_sales['month'] = df_sales['transaction_date'].dt.month
df_sales['month_name'] = df_sales['transaction_date'].dt.month_name()

df_sales['day'] = df_sales['transaction_date'].dt.day

df_sales['weekday'] = df_sales['transaction_date'].dt.day_name()

df_sales['weekend_flag'] = np.where(
    df_sales['weekday'].isin(['Saturday', 'Sunday']),
    'Weekend',
    'Weekday'
)

# %% [markdown]
# ### Creating Business KPIs
#
# #### Store managers care about:
#
# - Revenue
# - Profit
# - Fast moving products
# - Store performance
# - Weekend sales
# - Inventory availability

# %%
#Create Profit Column
df_sales['profit'] = df_sales['sales_amount'] - df_sales['cogs']

# %% [markdown]
# #### Daily Revenue Trend

# %%
daily_sales = df_sales.groupby('transaction_date').agg({
    'sales_amount':'sum',
    'profit':'sum',
    'qty_sold':'sum'
}).reset_index()
print(daily_sales)
# Out:
#     transaction_date  sales_amount    profit  qty_sold
# 0         2025-01-06      22565.33  10892.08     244.0
# 1         2025-01-07      19023.62   8714.13     217.0
# 2         2025-01-08      55369.09  25282.07     624.0
# 3         2025-01-09      48997.97  23184.77     543.0
# 4         2025-01-10      17933.63   7299.19     202.0
# ..               ...           ...       ...       ...
# 321       2026-11-04      36806.51  16259.06     435.0
# 322       2026-12-01      10685.27   3945.82     143.0
# 323       2026-12-02      45015.85  20638.41     405.0
# 324       2026-12-03      29851.97  11273.57     385.0
# 325       2026-12-04      21345.70   9489.11     247.0
#
# [326 rows x 4 columns]

# %%
plt.figure(figsize=(12, 5))
plt.plot( daily_sales['transaction_date'], daily_sales['sales_amount'])
plt.title("Daily Revenue Trend")
plt.xlabel("Transaction Date")
plt.ylabel("Total Sales Amount")
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %% [markdown]
# #### Weekday vs Weekend Performance

# %%
weekend_analysis = df_sales.groupby('weekend_flag').agg({
    'sales_amount':'sum',
    'profit':'sum',
    'qty_sold':'sum'
}).reset_index()
print(weekend_analysis)

#Revenue Comparison
total = 6661650.38 + 3820459.87

weekday_percent = (6661650.38 / total) * 100
weekend_percent = (3820459.87 / total) * 100

print("Weekday % :", round(weekday_percent,2))
print("Weekend % :", round(weekend_percent,2))
# Out:
#   weekend_flag  sales_amount        profit  qty_sold
# 0      Weekday    6661650.38  2.928978e+06   75720.0
# 1      Weekend    3820459.87  1.705381e+06   41275.0
# Weekday % : 63.55
# Weekend % : 36.45

# %% [markdown]
# - The analysis shows that weekday sales contribute significantly more revenue than weekend sales. Approximately 63% of total revenue is generated during weekdays, indicating stronger customer purchasing activity on working days. Weekend sales still contribute a substantial portion of revenue but remain lower in comparison. This insight can help store managers optimize staffing, inventory allocation, and promotional campaigns based on customer traffic patterns.
# ---
# #### Store manager can:
#
# - Keep higher staff availability on weekdays
# - Maintain more inventory during weekdays
# - Run weekend promotions to increase traffic
# - Identify if certain categories perform better on weekends

# %% [markdown]
# #### This can be misleading because:
#
# - Weekdays = 5 days
# - Weekend = 2 days
#
# So naturally weekdays may have higher totals.
#
#  so we calculate,
# #### Average sales per weekday vs per weekend day

# %%
daily_type_sales = df_sales.groupby(
    ['transaction_date', 'weekend_flag']
)['sales_amount'].sum().reset_index()

print("daily_type_sales : ")
print(daily_type_sales)
print()

avg_sales = daily_type_sales.groupby(
    'weekend_flag'
)['sales_amount'].mean().reset_index()

print('Average sales per weekday vs per weekend day ')
print(avg_sales)
# Out:
# daily_type_sales :
#     transaction_date weekend_flag  sales_amount
# 0         2025-01-06      Weekday      22565.33
# 1         2025-01-07      Weekday      19023.62
# 2         2025-01-08      Weekday      55369.09
# 3         2025-01-09      Weekday      48997.97
# 4         2025-01-10      Weekday      17933.63
# ..               ...          ...           ...
# 321       2026-11-04      Weekday      36806.51
# 322       2026-12-01      Weekday      10685.27
# 323       2026-12-02      Weekday      45015.85
# 324       2026-12-03      Weekday      29851.97
# 325       2026-12-04      Weekday      21345.70
#
# [326 rows x 3 columns]
#
# Average sales per weekday vs per weekend day
#   weekend_flag  sales_amount
# 0      Weekday  28714.010259
# 1      Weekend  40643.190106

# %% [markdown]
# #### so in summery :
# - Total weekday revenue > total weekend revenue
# - Average revenue per weekend day > average revenue per weekday
#
# #### This means:
#
# - Customers spend more per day on weekends.

# %% [markdown]
# #### Product Category Trends

# %%
category_sales = df_sales.groupby('product_category').agg({
    'sales_amount':'sum',
    'profit':'sum',
    'qty_sold':'sum'
}).sort_values(by='sales_amount', ascending=False)

print(category_sales)
# Out:
#                                   sales_amount       profit  qty_sold
# product_category
# Scholar Footwear Retro Legend       1920958.56  905344.3400   12569.0
# Scholar Footwear Trailblazer        1909759.99  927715.3700   20584.0
# Femme Footwear Trailblazer          1238790.65  436689.0400   12325.0
# Scholar Footwear Modern Legend      1062646.92  405024.2800   10731.0
# Scholar Footwear Flight Classic      767298.33  354519.3300    8926.0
# Scholar Footwear Court Casual        702385.90  281848.1800    9530.0
# Scholar Footwear Boot Collection     660152.85  358274.6600    6049.0
# Femme Footwear Court Casual          647820.37  240117.8001    7279.0
# Femme Footwear Boot Collection       304630.62  154503.4900    2321.0
# Femme Footwear Flight Classic        303495.26  140888.6700    2728.0
# Femme Footwear Retro Legend          177667.32   85156.4200     849.0
# Scholar Footwear Hardcourt           106883.73   41612.7700     702.0
# Junior Apparel Cozy Pullovers         91458.26   35560.5600    2988.0
# Junior Apparel Cozy Trousers          89165.69   35966.7900    3011.0
# Junior Apparel Crew Tees              86652.57   41014.0200    4078.0
# Scholar Footwear Sandals              85829.26   47945.0300    2050.0
# Scholar Footwear Trainer              83193.65   40710.0800     927.0
# Junior Apparel Printed Tees           39928.08   16830.5000    3534.0
# Femme Footwear Modern Legend          39802.63   15986.5400     374.0
# Scholar Footwear Canvas Styles        39080.26   20892.3500     703.0
# Junior Apparel Gift Bundles           33710.38   14372.7600    1235.0
# Junior Apparel Crop Pants             30942.51   12227.9400    1502.0
# Junior Apparel Denim Classics         17931.41    6661.9100     655.0
# Junior Apparel Trousers               16319.53    4722.7600     851.0
# Junior Apparel Outer Shells           11765.62    5422.2200     141.0
# Junior Apparel Miscellany              7753.71    4053.2100     179.0
# Junior Apparel Light Shells            6086.19     298.1300     174.0

# %% [markdown]
# #### Fast-Moving Inventory
# Fast-moving inventory means:
# - Products that sell quickly and frequently.
#
# Store managers care because:
#
# - these products need frequent restocking
# - stockouts hurt revenue
# - these products indicate customer demand
#
# ##### BEST METRIC : "qty_sold" , "number_of_transactions"

# %%
fast_moving = df_sales.groupby('product_category').agg({
    'qty_sold':'sum',
    'sales_amount':'sum',
    'number_of_transactions':'sum'
})

# %%
fast_moving = fast_moving.sort_values(
    by='qty_sold',
    ascending=False
)
fast_moving
# Out:
#                                   qty_sold  sales_amount  \
# product_category
# Scholar Footwear Trailblazer       20584.0    1909759.99
# Scholar Footwear Retro Legend      12569.0    1920958.56
# Femme Footwear Trailblazer         12325.0    1238790.65
# Scholar Footwear Modern Legend     10731.0    1062646.92
# Scholar Footwear Court Casual       9530.0     702385.90
# Scholar Footwear Flight Classic     8926.0     767298.33
# Femme Footwear Court Casual         7279.0     647820.37
# Scholar Footwear Boot Collection    6049.0     660152.85
# Junior Apparel Crew Tees            4078.0      86652.57
# Junior Apparel Printed Tees         3534.0      39928.08
# Junior Apparel Cozy Trousers        3011.0      89165.69
# Junior Apparel Cozy Pullovers       2988.0      91458.26
# Femme Footwear Flight Classic       2728.0     303495.26
# Femme Footwear Boot Collection      2321.0     304630.62
# Scholar Footwear Sandals            2050.0      85829.26
# Junior Apparel Crop Pants           1502.0      30942.51
# Junior Apparel Gift Bundles         1235.0      33710.38
# Scholar Footwear Trainer             927.0      83193.65
# Junior Apparel Trousers              851.0      16319.53
# Femme Footwear Retro Legend          849.0     177667.32
# Scholar Footwear Canvas Styles       703.0      39080.26
# Scholar Footwear Hardcourt           702.0     106883.73
# Junior Apparel Denim Classics        655.0      17931.41
# Femme Footwear Modern Legend         374.0      39802.63
# Junior Apparel Miscellany            179.0       7753.71
# Junior Apparel Light Shells          174.0       6086.19
# Junior Apparel Outer Shells          141.0      11765.62
#
#                                   number_of_transactions
# product_category
# Scholar Footwear Trailblazer                       23117
# Scholar Footwear Retro Legend                      13801
# Femme Footwear Trailblazer                         14536
# Scholar Footwear Modern Legend                     12207
# Scholar Footwear Court Casual                      10762
# Scholar Footwear Flight Classic                     9846
# Femme Footwear Court Casual                         8368
# Scholar Footwear Boot Collection                    6875
# Junior Apparel Crew Tees                            4273
# Junior Apparel Printed Tees                         3585
# Junior Apparel Cozy Trousers                        3243
# Junior Apparel Cozy Pullovers                       3195
# Femme Footwear Flight Classic                       3068
# Femme Footwear Boot Collection                      2949
# Scholar Footwear Sandals                            2175
# Junior Apparel Crop Pants                           1590
# Junior Apparel Gift Bundles                         1259
# Scholar Footwear Trainer                            1075
# Junior Apparel Trousers                              920
# Femme Footwear Retro Legend                         1003
# Scholar Footwear Canvas Styles                       776
# Scholar Footwear Hardcourt                           832
# Junior Apparel Denim Classics                        691
# Femme Footwear Modern Legend                         429
# Junior Apparel Miscellany                            199
# Junior Apparel Light Shells                          193
# Junior Apparel Outer Shells                          153

# %%
top_fast_moving = fast_moving.head(10)

top_fast_moving['qty_sold'].plot(kind='barh')
plt.xlabel("Quantity Sold")
plt.ylabel("Product Category")
plt.title("Top Fast-Moving Product Categories")
plt.gca().invert_yaxis()
plt.show()

# %%
df_inv.columns
# Out:
# Index(['start_date', 'end_date', 'stock_status', 'supplier', 'product_no',
#        'product_description', 'product_division', 'product_category',
#        'product_subcategory', 'product_segment', 'store', 'store_type',
#        'sales_channel', 'qty_on_hand', 'stocks_selling_amount',
#        'cost_of_stocks', 'stock_unit_selling_price', 'stock_unit_cost_price'],
#       dtype='str')

# %%
#sales amount group by sales type 
grp = df_sales.groupby('sales_type')['sales_amount'].sum()
grp

print(grp['Clearance'] + grp['Full Price'])
# Out:
# 8913865.42

# %%
df_inv['start_date_month'] = df_inv['start_date'].dt.month
df_inv['end_date_month'] = df_inv['end_date'].dt.month

df_inv_sorted = df_inv.sort_values(by="start_date")
df_inv_sorted[df_inv_sorted['product_category'] == 'Femme Footwear Trailblazer']
# Out:
#        start_date   end_date stock_status     supplier   product_no  \
# 284754 2025-06-01 2025-06-27   Full Price  Vendor 0166  PROD-124435
# 169957 2025-06-01 2025-06-19   Full Price  Vendor 0166  PROD-158661
# 34443  2025-06-01 2025-11-22   Full Price  Vendor 0166  PROD-124439
# 170134 2025-06-01 2025-07-31   Full Price  Vendor 0166  PROD-124435
# 170171 2025-06-01 2025-06-17   Full Price  Vendor 0166  PROD-158660
# ...           ...        ...          ...          ...          ...
# 240267 2026-04-24 9999-12-31   Full Price  Vendor 0166  PROD-124432
# 240266 2026-04-24 9999-12-31   Full Price  Vendor 0166  PROD-124436
# 240263 2026-04-24 9999-12-31   Full Price  Vendor 0166  PROD-124432
# 240262 2026-04-24 9999-12-31   Full Price  Vendor 0166  PROD-124432
# 240261 2026-04-24 9999-12-31   Full Price  Vendor 0166  PROD-124436
#
#                                       product_description product_division  \
# 284754  PROD-154330 SEG-512711 Femme Footwear Trailbla...   Femme Footwear
# 169957  PROD-174352 SEG-517028 Femme Footwear Trailbla...   Femme Footwear
# 34443   PROD-154324 SEG-512711 Femme Footwear Trailbla...   Femme Footwear
# 170134  PROD-154330 SEG-512711 Femme Footwear Trailbla...   Femme Footwear
# 170171  PROD-174353 SEG-517028 Femme Footwear Trailbla...   Femme Footwear
# ...                                                   ...              ...
# 240267  PROD-154327 SEG-512711 Femme Footwear Trailbla...   Femme Footwear
# 240266  PROD-154331 SEG-512711 Femme Footwear Trailbla...   Femme Footwear
# 240263  PROD-154327 SEG-512711 Femme Footwear Trailbla...   Femme Footwear
# 240262  PROD-154327 SEG-512711 Femme Footwear Trailbla...   Femme Footwear
# 240261  PROD-154331 SEG-512711 Femme Footwear Trailbla...   Femme Footwear
#
#                   product_category                product_subcategory  \
# 284754  Femme Footwear Trailblazer  Femme Footwear Trailblazer Zephyr
# 169957  Femme Footwear Trailblazer  Femme Footwear Trailblazer Zephyr
# 34443   Femme Footwear Trailblazer  Femme Footwear Trailblazer Zephyr
# 170134  Femme Footwear Trailblazer  Femme Footwear Trailblazer Zephyr
# 170171  Femme Footwear Trailblazer  Femme Footwear Trailblazer Zephyr
# ...                            ...                                ...
# 240267  Femme Footwear Trailblazer  Femme Footwear Trailblazer Zephyr
# 240266  Femme Footwear Trailblazer  Femme Footwear Trailblazer Zephyr
# 240263  Femme Footwear Trailblazer  Femme Footwear Trailblazer Zephyr
# 240262  Femme Footwear Trailblazer  Femme Footwear Trailblazer Zephyr
# 240261  Femme Footwear Trailblazer  Femme Footwear Trailblazer Zephyr
#
#                                      product_segment     store  \
# 284754  SEG-512711 Femme Footwear Trailblazer Zephyr  STR-1305
# 169957  SEG-517028 Femme Footwear Trailblazer Zephyr  STR-1105
# 34443   SEG-512711 Femme Footwear Trailblazer Zephyr  STR-1229
# 170134  SEG-512711 Femme Footwear Trailblazer Zephyr  STR-1074
# 170171  SEG-517028 Femme Footwear Trailblazer Zephyr  STR-1038
# ...                                              ...       ...
# 240267  SEG-512711 Femme Footwear Trailblazer Zephyr  STR-1353
# 240266  SEG-512711 Femme Footwear Trailblazer Zephyr  STR-1074
# 240263  SEG-512711 Femme Footwear Trailblazer Zephyr  STR-1107
# 240262  SEG-512711 Femme Footwear Trailblazer Zephyr  STR-1075
# 240261  SEG-512711 Femme Footwear Trailblazer Zephyr  STR-1157
#
#                store_type  sales_channel  qty_on_hand  stocks_selling_amount  \
# 284754  Retail Storefront  Channel Alpha            2                  340.0
# 169957  Retail Storefront  Channel Alpha            2                  340.0
# 34443   Retail Storefront  Channel Alpha            2                  340.0
# 170134  Retail Storefront  Channel Alpha            2                  340.0
# 170171  Retail Storefront  Channel Alpha            2                  340.0
# ...                   ...            ...          ...                    ...
# 240267  Retail Storefront  Channel Alpha            3                  510.0
# 240266  Retail Storefront  Channel Alpha            1                  170.0
# 240263  Retail Storefront  Channel Alpha            1                  170.0
# 240262  Retail Storefront  Channel Alpha            1                  170.0
# 240261  Retail Storefront  Channel Alpha            1                  170.0
#
#         cost_of_stocks  stock_unit_selling_price  stock_unit_cost_price  \
# 284754          160.16                     170.0                 80.080
# 169957          160.16                     170.0                 80.080
# 34443           160.24                     170.0                 80.120
# 170134          159.81                     170.0                 79.905
# 170171          160.16                     170.0                 80.080
# ...                ...                       ...                    ...
# 240267          253.59                     170.0                 84.530
# 240266           86.13                     170.0                 86.130
# 240263           86.02                     170.0                 86.020
# 240262           86.02                     170.0                 86.020
# 240261           86.02                     170.0                 86.020
#
#         start_date_month  end_date_month
# 284754                 6               6
# 169957                 6               6
# 34443                  6              11
# 170134                 6               7
# 170171                 6               6
# ...                  ...             ...
# 240267                 4              12
# 240266                 4              12
# 240263                 4              12
# 240262                 4              12
# 240261                 4              12
#
# [36368 rows x 20 columns]

# %%
current = df_inv[df_inv['end_date'] == '31-12-9999']
print(current)
current['qty_on_hand'].sum()
# Out:
#        start_date   end_date     stock_status     supplier   product_no  \
# 4      2026-02-10 9999-12-31       Full Price  Vendor 0134  PROD-183525
# 30     2025-10-07 9999-12-31       Full Price  Vendor 0262  PROD-176445
# 35     2025-11-17 9999-12-31       Full Price  Vendor 0169  PROD-166155
# 36     2025-11-17 9999-12-31       Full Price  Vendor 0169  PROD-166156
# 37     2025-11-17 9999-12-31       Full Price  Vendor 0169  PROD-166157
# ...           ...        ...              ...          ...          ...
# 284731 2026-04-20 9999-12-31  Markdown Tier 1  Vendor 0037  PROD-165076
# 284732 2026-04-20 9999-12-31       Full Price  Vendor 0010  PROD-165569
# 284733 2026-04-20 9999-12-31       Full Price  Vendor 0010  PROD-165579
# 284747 2026-04-15 9999-12-31       Full Price  Vendor 0169  PROD-168845
# 284748 2026-04-15 9999-12-31       Full Price  Vendor 0258  PROD-184466
#
#                                       product_description  product_division  \
# 4       PROD-111954 SEG-502325 Scholar Footwear Modern...  Scholar Footwear
# 30      PROD-178967 SEG-518011 Femme Footwear Trailbla...    Femme Footwear
# 35      PROD-149165 SEG-511428 Femme Footwear Trailbla...    Femme Footwear
# 36      PROD-149166 SEG-511428 Femme Footwear Trailbla...    Femme Footwear
# 37      PROD-149167 SEG-511428 Femme Footwear Trailbla...    Femme Footwear
# ...                                                   ...               ...
# 284731  PROD-104430 SEG-500638 Junior Apparel Crop Pan...    Junior Apparel
# 284732  PROD-179206 SEG-518043 Scholar Footwear Court ...  Scholar Footwear
# 284733  PROD-109667 SEG-502021 Femme Footwear Court Ca...    Femme Footwear
# 284747  PROD-149333 SEG-511443 Femme Footwear Trailbla...    Femme Footwear
# 284748  PROD-179901 SEG-518118 Scholar Footwear Trailb...  Scholar Footwear
#
#                       product_category  \
# 4       Scholar Footwear Modern Legend
# 30          Femme Footwear Trailblazer
# 35          Femme Footwear Trailblazer
# 36          Femme Footwear Trailblazer
# 37          Femme Footwear Trailblazer
# ...                                ...
# 284731       Junior Apparel Crop Pants
# 284732   Scholar Footwear Court Casual
# 284733     Femme Footwear Court Casual
# 284747      Femme Footwear Trailblazer
# 284748    Scholar Footwear Trailblazer
#
#                            product_subcategory  \
# 4        Scholar Footwear Modern Legend Summit
# 30           Femme Footwear Trailblazer Varied
# 35      Femme Footwear Trailblazer Equilibrium
# 36      Femme Footwear Trailblazer Equilibrium
# 37      Femme Footwear Trailblazer Equilibrium
# ...                                        ...
# 284731        Junior Apparel Crop Pants Varied
# 284732   Scholar Footwear Court Casual Trident
# 284733     Femme Footwear Court Casual Trident
# 284747  Femme Footwear Trailblazer Equilibrium
# 284748  Scholar Footwear Trailblazer Swift Run
#
#                                           product_segment     store  \
# 4        SEG-502325 Scholar Footwear Modern Legend Summit  STR-1253
# 30           SEG-518011 Femme Footwear Trailblazer Varied  STR-1253
# 35      SEG-511428 Femme Footwear Trailblazer Equilibrium  STR-1253
# 36      SEG-511428 Femme Footwear Trailblazer Equilibrium  STR-1145
# 37      SEG-511428 Femme Footwear Trailblazer Equilibrium  STR-1148
# ...                                                   ...       ...
# 284731        SEG-500638 Junior Apparel Crop Pants Varied  STR-1198
# 284732   SEG-518043 Scholar Footwear Court Casual Trident  STR-1344
# 284733     SEG-502021 Femme Footwear Court Casual Trident  STR-1235
# 284747  SEG-511443 Femme Footwear Trailblazer Equilibrium  STR-1006
# 284748  SEG-518118 Scholar Footwear Trailblazer Swift Run  STR-1219
#
#                store_type  sales_channel  qty_on_hand  stocks_selling_amount  \
# 4       Retail Storefront  Channel Alpha            4                 360.00
# 30      Retail Storefront  Channel Alpha            1                 150.00
# 35      Retail Storefront  Channel Alpha            2                 230.00
# 36      Retail Storefront  Channel Alpha            2                 230.00
# 37      Retail Storefront  Channel Alpha            2                 230.00
# ...                   ...            ...          ...                    ...
# 284731  Retail Storefront  Channel Alpha            2                  39.98
# 284732  Retail Storefront  Channel Alpha            1                  80.00
# 284733  Retail Storefront  Channel Alpha            2                 240.00
# 284747  Retail Storefront  Channel Alpha            1                 160.00
# 284748  Retail Storefront  Channel Alpha            3                 267.00
#
#         cost_of_stocks  stock_unit_selling_price  stock_unit_cost_price  \
# 4               182.16                     90.00                 45.540
# 30               50.00                    150.00                 50.000
# 35              115.13                    115.00                 57.565
# 36              115.12                    115.00                 57.560
# 37              115.12                    115.00                 57.560
# ...                ...                       ...                    ...
# 284731           26.00                     19.99                 13.000
# 284732           36.80                     80.00                 36.800
# 284733          110.40                    120.00                 55.200
# 284747           68.31                    160.00                 68.310
# 284748          130.68                     89.00                 43.560
#
#         start_date_month  end_date_month
# 4                      2              12
# 30                    10              12
# 35                    11              12
# 36                    11              12
# 37                    11              12
# ...                  ...             ...
# 284731                 4              12
# 284732                 4              12
# 284733                 4              12
# 284747                 4              12
# 284748                 4              12
#
# [22701 rows x 20 columns]
# np.int64(37187)

# %% [markdown]
# ### product having dead stock
# - dead stock means - product is unsold from too many days or too much less sale.

# %%
current_date = datetime.datetime(2026, 6, 3)
df_inv['days_in_inventory'] = (current_date - df_inv['start_date']).dt.days

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")

plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_inv, x='days_in_inventory', y='qty_on_hand', alpha=0.6, color='teal')
plt.axvline(x=180, color='red', linestyle='--', label='180 Days Threshold')
plt.axhline(y=50, color='orange', linestyle='--', label='50 Units Threshold')
plt.title('Inventory Analysis: Qty on Hand vs. Days in Inventory')
plt.xlabel('Days in Inventory')
plt.ylabel('Qty on Hand')
plt.legend()
plt.show()

# %%
df_inv[(df_inv['days_in_inventory'] > 180) & (df_inv['qty_on_hand'] > 50)]['product_category'].unique()
# Out:
# <ArrowStringArray>
# ['Femme Footwear Court Casual']
# Length: 1, dtype: str

# %%
df_sales.columns
# Out:
# Index(['transaction_date', 'sales_type', 'is_return', 'supplier', 'product_no',
#        'product_description', 'product_division', 'product_category',
#        'product_subcategory', 'product_segment', 'store', 'sales_channel',
#        'qty_sold', 'sales_amount', 'cogs', 'number_of_transactions', 'year',
#        'month', 'month_name', 'day', 'weekday', 'weekend_flag', 'profit'],
#       dtype='str')

# %%
inv_summary = df_inv.groupby('supplier').agg(
    Avg_Days_in_Inventory=('days_in_inventory', 'mean'),
    Total_Qty_on_Hand=('qty_on_hand', 'sum')
).reset_index()

sales_summary = df_sales.groupby('supplier').agg(
    Total_Transactions=('is_return', 'count'),
    Total_Returns=('is_return', 'sum'),
    Total_Sales_Amount=('sales_amount', 'sum'),
    Total_Cogs=('cogs', 'sum')
).reset_index()


print(inv_summary)
print(sales_summary)
# Out:
#        supplier  Avg_Days_in_Inventory  Total_Qty_on_Hand
# 0   Vendor 0008             236.699065               1738
# 1   Vendor 0010             222.016072              37971
# 2   Vendor 0025             201.827586                723
# 3   Vendor 0027             209.003623                868
# 4   Vendor 0037             187.773028               4691
# 5   Vendor 0039             101.528428                536
# 6   Vendor 0042             206.850806                409
# 7   Vendor 0052             239.569980                848
# 8   Vendor 0054             255.498427              10826
# 9   Vendor 0064             204.040083              26290
# 10  Vendor 0082             225.038760                258
# 11  Vendor 0084             200.379310                377
# 12  Vendor 0094             212.638215               3088
# 13  Vendor 0106             194.462563              44683
# 14  Vendor 0126             238.714715               2885
# 15  Vendor 0134             219.047002             106190
# 16  Vendor 0141             202.845056               2677
# 17  Vendor 0146             229.034682                885
# 18  Vendor 0155             243.949183               1391
# 19  Vendor 0165             101.099831               1103
# 20  Vendor 0166             221.787150             257767
# 21  Vendor 0169             225.211253              71384
# 22  Vendor 0193             283.450739                718
# 23  Vendor 0198             218.522232              10185
# 24  Vendor 0245             204.537931               1014
# 25  Vendor 0246             215.708679              38727
# 26  Vendor 0255             219.184292               2863
# 27  Vendor 0258             233.046166              16532
# 28  Vendor 0260             154.590814                880
# 29  Vendor 0262             205.929213               4900
#        supplier  Total_Transactions  Total_Returns  Total_Sales_Amount  \
# 0   Vendor 0008                 530             23            45562.33
# 1   Vendor 0010                7488            474           490924.49
# 2   Vendor 0025                  74              2             1057.47
# 3   Vendor 0027                  83              1             1130.43
# 4   Vendor 0037                1161             46            28432.74
# 5   Vendor 0039                 164             12             6250.25
# 6   Vendor 0042                 192              7             3421.90
# 7   Vendor 0052                 236             12            13340.49
# 8   Vendor 0054                1928             68            77121.67
# 9   Vendor 0064                4278            434           423710.82
# 10  Vendor 0082                  68              2              607.72
# 11  Vendor 0084                  66              1             1205.88
# 12  Vendor 0094                 408              4             3687.75
# 13  Vendor 0106                7362            224           175354.18
# 14  Vendor 0126                 550              7             7154.39
# 15  Vendor 0134               24567           1552          3204043.60
# 16  Vendor 0141                 529             15             8757.30
# 17  Vendor 0146                 137              2             4606.85
# 18  Vendor 0155                 352             12             5105.63
# 19  Vendor 0165                 263             27            11687.00
# 20  Vendor 0166               42222           2516          3290375.40
# 21  Vendor 0169               20218           1353          1703035.19
# 22  Vendor 0193                 220             11            12581.82
# 23  Vendor 0198                1872             29            20212.24
# 24  Vendor 0245                 116              2              972.45
# 25  Vendor 0246                5017            309           537752.65
# 26  Vendor 0255                 533             26            25739.77
# 27  Vendor 0258                3587            214           258547.61
# 28  Vendor 0260                 240             13             8244.95
# 29  Vendor 0262                1290             93           111485.28
#
#       Total_Cogs
# 0   2.367854e+04
# 1   2.882308e+05
# 2   3.852000e+02
# 3   5.330000e+02
# 4   1.811422e+04
# 5   2.274000e+03
# 6   2.208000e+03
# 7   6.085160e+03
# 8   3.344042e+04
# 9   2.080845e+05
# 10  4.410000e+02
# 11  9.845000e+02
# 12  2.898000e+03
# 13  9.997855e+04
# 14  2.984500e+03
# 15  1.791679e+06
# 16  4.007500e+03
# 17  2.561230e+03
# 18  2.303630e+03
# 19  4.924800e+03
# 20  1.905179e+06
# 21  9.611047e+05
# 22  6.917490e+03
# 23  1.278950e+04
# 24  7.627500e+02
# 25  2.420992e+05
# 26  1.210275e+04
# 27  1.321054e+05
# 28  5.933560e+03
# 29  7.295996e+04

# %%
vendor_scorecard = pd.merge(sales_summary, inv_summary, on='supplier', how='inner')
vendor_scorecard



# Filter out very low-volume suppliers to maintain data consistency
# Let's consider suppliers with more than 100 sales transactions
reliable_scorecard = vendor_scorecard[vendor_scorecard['Total_Transactions'] > 100]
print(reliable_scorecard.columns)
print(reliable_scorecard)
# Round metrics for readability

reliable_scorecard['Return Rate'] = reliable_scorecard['Return Rate'].round(2)
# The math happening in the background:
# ((Total Sales - Total COGS) / Total Sales) * 100
print(sales_summary.columns)
sales_summary['Gross Profit Margin'] = ((sales_summary['Total_Sales_Amount'] - sales_summary['Total_Cogs']) / sales_summary['Total_Sales_Amount']) * 100
reliable_scorecard['Gross Profit Margin'] = reliable_scorecard['Gross Profit Margin'].round(2)
reliable_scorecard['Avg_Days_in_Inventory'] = reliable_scorecard['Avg_Days_in_Inventory'].round(1)


# ==========================================
# STEP 4: PRINT RESULTS TO DETECT PATTERNS
# ==========================================
print("--- TOP 5 SUPPLIERS WITH LOWEST RETURN RATES (HIGHEST QUALITY) ---")
print(reliable_scorecard.sort_values(by='Return Rate %', ascending=True).head(5)[
    ['supplier', 'Return Rate %', 'Gross Profit Margin %', 'Avg_Days_in_Inventory']
].to_string(index=False))

print("\n--- TOP 5 SUPPLIERS WITH HIGHEST RETURN RATES (QUALITY ISSUES) ---")
print(reliable_scorecard.sort_values(by='Return Rate %', ascending=False).head(5)[
    ['supplier', 'Return Rate %', 'Gross Profit Margin %', 'Avg_Days_in_Inventory']
].to_string(index=False))
# Out:
# Index(['supplier', 'Total_Transactions', 'Total_Returns', 'Total_Sales_Amount',
#        'Total_Cogs', 'Return Rate %', 'Return Rate', 'Gross Profit Margin %',
#        'Gross Profit Margin', 'Avg_Days_in_Inventory', 'Total_Qty_on_Hand'],
#       dtype='str')
#        supplier  Total_Transactions  Total_Returns  Total_Sales_Amount  \
# 0   Vendor 0008                 530             23            45562.33
# 1   Vendor 0010                7488            474           490924.49
# 4   Vendor 0037                1161             46            28432.74
# 5   Vendor 0039                 164             12             6250.25
# 6   Vendor 0042                 192              7             3421.90
# 7   Vendor 0052                 236             12            13340.49
# 8   Vendor 0054                1928             68            77121.67
# 9   Vendor 0064                4278            434           423710.82
# 12  Vendor 0094                 408              4             3687.75
# 13  Vendor 0106                7362            224           175354.18
# 14  Vendor 0126                 550              7             7154.39
# 15  Vendor 0134               24567           1552          3204043.60
# 16  Vendor 0141                 529             15             8757.30
# 17  Vendor 0146                 137              2             4606.85
# 18  Vendor 0155                 352             12             5105.63
# 19  Vendor 0165                 263             27            11687.00
# 20  Vendor 0166               42222           2516          3290375.40
# 21  Vendor 0169               20218           1353          1703035.19
# 22  Vendor 0193                 220             11            12581.82
# 23  Vendor 0198                1872             29            20212.24
# 24  Vendor 0245                 116              2              972.45
# 25  Vendor 0246                5017            309           537752.65
# 26  Vendor 0255                 533             26            25739.77
# 27  Vendor 0258                3587            214           258547.61
# 28  Vendor 0260                 240             13             8244.95
# 29  Vendor 0262                1290             93           111485.28
#
#       Total_Cogs  Return Rate %  Return Rate  Gross Profit Margin %  \
# 0   2.367854e+04       4.339623     4.339623              48.030445
# 1   2.882308e+05       6.330128     6.330128              41.288152
# 4   1.811422e+04       3.962102     3.962102              36.290980
# 5   2.274000e+03       7.317073     7.317073              63.617455
# 6   2.208000e+03       3.645833     3.645833              35.474444
# 7   6.085160e+03       5.084746     5.084746              54.385783
# 8   3.344042e+04       3.526971     3.526971              56.639398
# 9   2.080845e+05      10.144928    10.144928              50.889973
# 12  2.898000e+03       0.980392     0.980392              21.415497
# 13  9.997855e+04       3.042651     3.042651              42.984792
# 14  2.984500e+03       1.272727     1.272727              58.284354
# 15  1.791679e+06       6.317418     6.317418              44.080694
# 16  4.007500e+03       2.835539     2.835539              54.238178
# 17  2.561230e+03       1.459854     1.459854              44.403877
# 18  2.303630e+03       3.409091     3.409091              54.880593
# 19  4.924800e+03      10.266160    10.266160              57.860871
# 20  1.905179e+06       5.958979     5.958979              42.098423
# 21  9.611047e+05       6.692057     6.692057              43.565187
# 22  6.917490e+03       5.000000     5.000000              45.019957
# 23  1.278950e+04       1.549145     1.549145              36.723985
# 24  7.627500e+02       1.724138     1.724138              21.564091
# 25  2.420992e+05       6.159059     6.159059              54.979446
# 26  1.210275e+04       4.878049     4.878049              52.980349
# 27  1.321054e+05       5.965988     5.965988              48.904815
# 28  5.933560e+03       5.416667     5.416667              28.034009
# 29  7.295996e+04       7.209302     7.209302              34.556419
#
#     Gross Profit Margin  Avg_Days_in_Inventory  Total_Qty_on_Hand
# 0             48.030445             236.699065               1738
# 1             41.288152             222.016072              37971
# 4             36.290980             187.773028               4691
# 5             63.617455             101.528428                536
# 6             35.474444             206.850806                409
# 7             54.385783             239.569980                848
# 8             56.639398             255.498427              10826
# 9             50.889973             204.040083              26290
# 12            21.415497             212.638215               3088
# 13            42.984792             194.462563              44683
# 14            58.284354             238.714715               2885
# 15            44.080694             219.047002             106190
# 16            54.238178             202.845056               2677
# 17            44.403877             229.034682                885
# 18            54.880593             243.949183               1391
# 19            57.860871             101.099831               1103
# 20            42.098423             221.787150             257767
# 21            43.565187             225.211253              71384
# 22            45.019957             283.450739                718
# 23            36.723985             218.522232              10185
# 24            21.564091             204.537931               1014
# 25            54.979446             215.708679              38727
# 26            52.980349             219.184292               2863
# 27            48.904815             233.046166              16532
# 28            28.034009             154.590814                880
# 29            34.556419             205.929213               4900
# Index(['supplier', 'Total_Transactions', 'Total_Returns', 'Total_Sales_Amount',
#        'Total_Cogs', 'Return Rate %', 'Return Rate', 'Gross Profit Margin %',
#        'Gross Profit Margin'],
#       dtype='str')
# --- TOP 5 SUPPLIERS WITH LOWEST RETURN RATES (HIGHEST QUALITY) ---
#    supplier  Return Rate %  Gross Profit Margin %  Avg_Days_in_Inventory
# Vendor 0094       0.980392              21.415497                  212.6
# Vendor 0126       1.272727              58.284354                  238.7
# Vendor 0146       1.459854              44.403877                  229.0
# Vendor 0198       1.549145              36.723985                  218.5
# Vendor 0245       1.724138              21.564091                  204.5
#
# --- TOP 5 SUPPLIERS WITH HIGHEST RETURN RATES (QUALITY ISSUES) ---
#    supplier  Return Rate %  Gross Profit Margin %  Avg_Days_in_Inventory
# Vendor 0165      10.266160              57.860871                  101.1
# Vendor 0064      10.144928              50.889973                  204.0
# Vendor 0039       7.317073              63.617455                  101.5
# Vendor 0262       7.209302              34.556419                  205.9
# Vendor 0169       6.692057              43.565187                  225.2
